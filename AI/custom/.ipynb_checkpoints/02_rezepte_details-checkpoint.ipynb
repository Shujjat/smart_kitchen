# %% [markdown]
# # [Chefkoch.de](http://www.chefkoch.de/)
# ------
#
# ## Ziel:
# ### Scraping the main recipe collection of over 300,000 different recipes (part 2)

# %%
import datetime as dt
import csv
from bs4 import BeautifulSoup
from lxml import html
from datetime import datetime
from multiprocessing import Pool
from random import uniform, choice
from time import sleep, time
import requests
import os.path
import re
import os

# %%
DATAST_FOLDER = 'input/test/'
IMGS_FOLDER  = 'input/images/search_thumbnails/'
DFILE_NAME    = 'recipe_details'  + '.csv'
PIC_LIST      = 'pic_list' + '.csv'

# %% [markdown]
# #### This time the goal is to load the ingredient list, the preparation, the tags and all pictures of each individual recipe.
#
# ### example:

# %%
from IPython.display import Image
PATH = "./"
Image(filename = PATH + "burger.jpg", width='100%', height=140)

# %% [markdown]
# This recipe has the tags ** baking ** and ** bread or rolls **.
# It also has 31 more pictures that we still need.

# %%
def get_list_of_recipes():
    recipe_links = []
    chef_file = DATAST_FOLDER + 'chefkoch.csv'
    chef_file
    #print(chef_file)
    with open(chef_file, 'r') as f:
        chefkoch = csv.reader(f)
        for row in chefkoch:
            try:
                recipe_links.append(row[-2])
            except: 
                continue 
    return(recipe_links)

def get_list_of_scraped_recipes():
    
    recipe_links = []
    recipes_file = DATAST_FOLDER + DFILE_NAME
    if os.path.isfile(recipes_file):
        with open(recipes_file, 'r') as f:
            chefkoch = csv.reader(f)
            for row in chefkoch:
                try:
                    recipe_links.append(row[0])
                except: 
                    continue
    #print(recipe_links)
    #print('**************')
    return(recipe_links)

def list_to_scrape():
    
    l_scraped = get_list_of_scraped_recipes()
    #print('-----------')
    #print(l_scraped)
    l_all     = get_list_of_recipes()
    
    
    #print('-----------')
    
    l_to_scrape = list(set(l_all) - set(l_scraped))
    #print('Difference of sets:', len(l_to_scrape))
    
    return(l_to_scrape)
recipe_links = list_to_scrape()
#recipe_links

# %%
#recipe_links

# %%
#recipe_links

# %%
def write_recipe_details(data):
    print(data)
    dpath = DATAST_FOLDER + DFILE_NAME
   
    with open(dpath, 'a', newline='') as f:
        writer = csv.writer(f)
        try:
            writer.writerow((data['link'],
                             data['ingredients'],
                             '------------------------',
                             #data['zubereitung'],
                             #data['tags'],
                             #data['gedruckt:'],
                             #data['n_pics']
                             #data['reviews'],
                             #data['gespeichert:'],
                             #data['Freischaltung:'],
                             #data['author_registration_date'],
                             #data['author_reviews']
                            ))
        except:
            writer.writerow('')

# %%
dpath = DATAST_FOLDER + DFILE_NAME
dpath
# Out:
# 'input/test/recipe_details.csv'

# %% [markdown]
# ### Die Links zu den Bildern werden in einer Liste gespeichert und seperat runtergeladen.

# %%
def write_picture_list(pics):
    dpath = DATAST_FOLDER + PIC_LIST
    with open(dpath, 'a', newline='') as f:
        writer = csv.writer(f)
        try:
            writer.writerow(pics)
        except:
            writer.writerow('')

# %%
def get_stats(soup):
    stats = {}
    # DROPPED
    # anzahl bewertungen
    reviews = soup.find('div', id="recipe__rating").find('span', class_ = "rating__total-votes m-r-s").text
    #stats['reviews'] = reviews
    
    # andere statistiken
    if reviews != '(0)':
        stats_table = soup.find('div', id="recipe-statistic").find_all('table')[1].find_all('tr')[1:5]
    else:
        stats_table = soup.find('div', id="recipe-statistic").find_all('table')[0].find_all('tr')[1:5]
        
    for tr in stats_table:
        stat_name  = tr.find_all('td')[0].text.strip()
        stat_value = tr.find_all('td')[1].text.strip().split(' ')[0]
        stats[stat_name] = stat_value
    return(stats)

def get_n_pictures(html_text):
    tree = html.fromstring(html_text)
    # alle bilder links
    links_pics = tree.xpath('//div[contains(@id, "slider")]//img[@class="slideshow-image lazyload"]/@src')
    return links_pics

def get_zubereitung(soup):
    zuber = soup.find('div', id="rezept-zubereitung").text.strip()
    zuber = zuber.replace('\n', ' ').replace('\r', '')
    return zuber

def get_ingredients(soup):
    # liste von zubereitungen
    ingredient_list = []
    amounts_ingredients = soup.find('table', class_="ingredients table-header").find_all('tr')
    
    for tr in amounts_ingredients:
        am = tr.find_all('td')[0].text.strip() # amount
        td = tr.find_all('td')[1].text.strip().split(',')[0] # ingredient
        td = re.sub('\(.*?\)','', td)
        ingr = am + '@' + td
        ingredient_list.append(ingr)
    
    #print(str.join(',', ingredient_list))
    return(str.join(',', ingredient_list))

def get_tags(soup):
    tags = []
    tag_cloud = soup.find('ul', class_ = 'tagcloud').find_all('li')
    for li in tag_cloud:
        tags.append(li.find('a').text.strip())
        
    return(str.join(',', tags))

# DROPPED
#def get_author_info(soup):
#    author = {}
#    author['author_registration_date'] = soup.find('div', class_="user-details").find('p').find('br').previous_sibling.strip()
#    author['author_reviews'] = soup.find('div', class_="user-details").find('p').find('br').next_sibling.strip()
#    return(author)

# %%
desktop_agents = ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/602.2.14 (KHTML, like Gecko) Version/10.0.1 Safari/602.2.14',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0']

def random_headers():
    return {'User-Agent': choice(desktop_agents),'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'}

# %%
failed_urls = []

# %%
def get_html(url):
    
    i = 5
    while i > 0:
        try:
            page = requests.get(url, headers=random_headers())
            if page.status_code != requests.codes.ok:
                page.raise_for_status()
            else:
                print(url)
                return page.text        
        except requests.exceptions.RequestException as e:
            print("Could not fetch " + str(url))
            print(e)
            # sichere url zu einer Liste von fehlgeschlagenen Links
            failed_urls.append(url)
            sleep(5)
            i = i - 1
            continue

    #print("Link zum 5. Mal nicht abrufbar " + str(url) + " ,abbrechen")
    return None

# %%
def get_recipe_info(url):
   
    url=url[22:]
    print(url)
    print('11111111')
    sleep_time = uniform(2, 4)
    sleep(sleep_time)
    
    html_text = get_html(url)
    #print(url[22:])
    
    
   
    try:
        print('2222222222')
        soup = BeautifulSoup(html_text, 'lxml')
        print('3333333333')
        # tags ingredients preparation
        #print(soup)
        ingredient_list = get_ingredients(soup)
        print('44444444444')
        #tags = get_tags(soup)
        print('5555555555555')
        #prep = get_zubereitung(soup)
        print('666666666666666')
        # pics
        list_pics = get_n_pictures(html_text)
        print('777777777777777777')
        #n_pics = len(list_pics)
        
        # update dictionary
        #stats = get_stats(soup)
        #author_info = get_author_info(soup)
        print('8888888888')
        # write dictionary
        data = {'link' : url,
                'ingredients' : ingredient_list,
                }
        #data.update(stats)
        print('99999999999999999')
        #data.update(author_info)
        
    except:
        print('Excepting')
        data = ''
        list_pics = ['error']
        
    
   
    
    write_recipe_details(data)
    
    #write_picture_list(list_pics)
#print(recipe_links)    
get_recipe_info(recipe_links[10])
get_recipe_info(recipe_links[20])
get_recipe_info(recipe_links[30])
# Out:
# https://www.chefkoch.de/rezepte/3837871584791506/Brotfrikadellen.html
# 11111111
# https://www.chefkoch.de/rezepte/3837871584791506/Brotfrikadellen.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3837871584791506/Brotfrikadellen.html', 'ingredients': '150                                g@Altbrot,50                                g@Brötchen oder Weißbrot,2                                m.-große@Ei,1                                große@Zwiebel,@Petersilie,¼                                Liter@Milch,50                                g@Paniermehl,@Öl zum Braten,@Salz und Pfeffer,evtl.@Knoblauchpulver,125                                g@Schinkenwürfel'}
# https://www.chefkoch.de/rezepte/3837901584794946/Granatapfelerfrischungsgetraenk-Hades-und-Persephone.html
# 11111111
# https://www.chefkoch.de/rezepte/3837901584794946/Granatapfelerfrischungsgetraenk-Hades-und-Persephone.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3837901584794946/Granatapfelerfrischungsgetraenk-Hades-und-Persephone.html', 'ingredients': '3                                Beutel@Pfefferminztee,850                                ml@Wasser'}
# https://www.chefkoch.de/rezepte/3837941584796251/Falsches-Filet-Sous-Vide.html
# 11111111
# https://www.chefkoch.de/rezepte/3837941584796251/Falsches-Filet-Sous-Vide.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3837941584796251/Falsches-Filet-Sous-Vide.html', 'ingredients': '2                                kg@Rinderschulter ,1                                kg@Knochen,1                                Bund@Suppengrün,1                                Pck.@Champignons,2                                große@Gemüsezwiebel,3                                Zehe/n@Knoblauch,1                                Flasche@Rotwein,2                                EL@Kräuter der Provence,1                                Pck.@Spätzle,@Sonnenblumenöl,@Butterschmalz,@Salz und Pfeffer,@Butter,@Speisestärke zum Binden'}

# %%
#recipe_links
#get_recipe_info( recipe_links)

# %%
start_time = datetime.now()
print(start_time)
with Pool(15) as p:
    
    p.map(get_recipe_info, recipe_links)
print("--- %s seconds ---" % (datetime.now() - start_time))
# Out:
# 2020-05-25 16:50:23.575706
# https://www.chefkoch.de/rezepte/3837551584725752/Gruenes-vegetarisches-Curry-aus-dem-Roemertopf.html
# 11111111
# https://www.chefkoch.de/rezepte/3838451584888073/Sauerkirsch-Kurkuma-Trunk-a-la-Kristina.html
# https://www.chefkoch.de/rezepte/3837871584791506/Brotfrikadellen.html
# https://www.chefkoch.de/rezepte/3858401587453080/Weissbrot.html
# https://www.chefkoch.de/rezepte/3837621584728781/Low-Carb-Weisskohl-Oliven-Slaw-mit-Haehnchen-Kebab.html
# 11111111
# https://www.chefkoch.de/rezepte/3837901584794946/Granatapfelerfrischungsgetraenk-Hades-und-Persephone.html
# https://www.chefkoch.de/rezepte/3858371587451543/Kung-Pao-Huhn-mit-Gemuese.html
html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3858861587532025/Sambal-Bangkok-ala-Siu.html', 'ingredients': '200                                g@Kokoswasser,4                                g@Hühnerbrühe ,130                                g@Zucker,20                                g@Essigessenz'}
# https://www.chefkoch.de/rezepte/3858441587463398/Ballotine-vom-Perlhuhn-mit-Morchelrahm-und-Brezen.html
# 2222222222
# 3333333333
# Excepting
#
# https://www.chefkoch.de/rezepte/3859111587559003/Malzbierbrot-mit-Roestzwiebeln-und-Quark-aus-dem-Topf.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3859111587559003/Malzbierbrot-mit-Roestzwiebeln-und-Quark-aus-dem-Topf.html', 'ingredients': '500                                g@Weizenmehl Type 405 oder 550,1                                Tüte/n@Backpulver,2                                TL@Salz,250                                g@Sahnequark,1@Ei,200                                ml@Malzbier,100                                g@Röstzwiebeln'}
# https://www.chefkoch.de/rezepte/3838341584880200/Spaghetti-Gemuesepfanne-mit-Pesto.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3838341584880200/Spaghetti-Gemuesepfanne-mit-Pesto.html', 'ingredients': '100                                g@Babyspinat,100                                g@Walnüsse,3@Knoblauchzehe,1@Pak Choi,150                                ml@Olivenöl,½@Limette,@Rapsöl zum Anbraten,1                                kleine@Zucchini,1@Paprikaschote,200                                g@Schafskäse,@Salz und Pfeffer,n. B.@Chili,@Kräuter,250                                g@Spaghetti,10                                kleine@Rispentomate'}
# https://www.chefkoch.de/rezepte/3838241584871238/Moehrensalat-mit-wuerzigen-Kichererbsen-und-Hummus.html
# 2222222222
# 3333333333
# Excepting
#
# https://www.chefkoch.de/rezepte/3858341587449956/Coquelets-auf-dem-Grillspiess.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3858341587449956/Coquelets-auf-dem-Grillspiess.html', 'ingredients': '4@Stubenküken ,100                                g@Butter,einige Stiele@Kräuter,4                                EL@Olivenöl,etwas@Rosmarin,n. B.@Salz und Pfeffer,n. B.@Hähnchengewürz oder ersatzweise Fleischgewürz'}
# https://www.chefkoch.de/rezepte/3838221584870168/Pikante-Hackfleischsauce-a-la-Annlaise.html
# 2222222222
# 3333333333
# 44444444444
# 5555555555555
# 666666666666666
# 777777777777777777
# 8888888888
# 99999999999999999
# {'link': 'https://www.chefkoch.de/rezepte/3838221584870168/Pikante-Hackfleischsauce-a-la-Annlaise.html', 'ingredients': '1                                Bund@Liebstöckel,1                                Bund@Basilikum,1                                Bund@Oregano,500                                g@Hackfleisch,300                                g@Zwiebel,4@Knoblauchzehe,3@Peperoni,1                                kl. Stange(n)@Lauch,1                                m.-große@Möhre,150                                g@Knollensellerie,@Salz und Pfeffer,4                                EL@Öl,100                                g@Butter,40                                g@Mehl'}
# --- 0:00:33.880651 seconds ---

# %% [markdown]
# ### 15'360 recipes were downloaded per hour in * recipe_details_27-12-2017.csv *. Total runtime: 20h 36min. The cvs file now contains the very important data

# %%
DFILE_NAME    = 'recipe_details' +  '.csv'
PIC_LIST      = 'pic_list' + '.csv'

import pandas as pd
print(DATAST_FOLDER+DFILE_NAME)
recipe_details = pd.read_csv(DATAST_FOLDER+DFILE_NAME, header=None)
recipe_details.head() # erste 5 zeilen
# Out:
# input/test/recipe_details.csv
#                                                    0  \
# 0  https://www.chefkoch.de/rezepte/38584515874650...
# 1  https://www.chefkoch.de/rezepte/38375715847269...
# 2  https://www.chefkoch.de/rezepte/38595415876310...
# 3  https://www.chefkoch.de/rezepte/38375515847257...
# 4  https://www.chefkoch.de/rezepte/38383715848810...
#
#                                                    1
# 0  18                                Blätter@Wirs...
# 1  250                                g@Penne,150...
# 2  1 ½                                kg@Rinderha...
# 3  250                                g@Rahmspina...
# 4  400                                g@Banane,40...

# %% [markdown]
# # Download the images
#
# So far only the thumbnails have been downloaded. The size is 164x140. The thumbnails can be found under input / images / search_thumbnails. Example:

# %%
#from IPython.display import Image
#PATH = "input/images/search_thumbnails/"
#Image(filename = PATH + "recipe-1742451283182013-0.jpg", width=164, height=140)

# %% [markdown]
# Chefkoch erlaubt seinen Nutzern Bilder vom Rezept hochzuladen. Oftmals ist es so, dass es mehr als ein Bild pro Rezept gibt. Um möglichst viele Daten zu haben, ladet man natürlich alle Bilder herunter. Die Links sind in der Datei *pic_list_27-12-2017.csv*

# %%
import pandas as pd
pic_list = pd.read_csv('input/test/fixed.csv', header=None)
pic_list.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-6c535a955d43> in <module>
#       1 import pandas as pd
# ----> 2 pic_list = pd.read_csv('input/test/fixed.csv', header=None)
#       3 pic_list.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'input/test/fixed.csv' does not exist: b'input/test/fixed.csv'

# %% [markdown]
# Zuerst überprüfen wir ob die Liste leere Einträge hat, welche entfernt werden müssen.

# %%
#pic_list[pic_list[1].isnull()] # 2 NaN entries

# %%
#pic_list = pic_list.drop(pic_list.index[105484])
#pic_list = pic_list.drop(pic_list.index[140099])

# %%
#pic_list[pic_list[1].isnull()] # No more NaN entries

# %% [markdown]
# **689'651** Bilder von **107'052** Rezepten müssen noch heruntergeladen werden.
#
# ### Bisherige Statistik: (Stand: Ende Dezember 2017)
#     Chefkoch.de enthält:
#         - Insgesamt 879'620 Bilder
#         - 316'756 Rezepte
#             - Davon enthalten 189'969 ein oder mehr Bilder
#                 - Davon enthalten 107'052 Rezepte mehr als 2 Bilder
#             - 126'787 enthalten kein Bild

# %%
#links = []
#for index, row in pic_list.iterrows():
    #link = row[1].split(',')
    #if len(link) > 1: links.append(link[1:]) # ignorieren falls weniger als ein Link vorhanden

        
#print(len(links))
#count=0
#for ll in links:
    #for l in ll:
        #count+=1
#print(count)

# %%
links[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-58b217ff09cc> in <module>
# ----> 1 links[0]
#
# NameError: name 'links' is not defined

# %%
partial_ids = []
for link in links:
    partial_ids.append(link[0].split('/')[6]) # extrakt partial id
partial_ids[:11]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-66d1a2cc948d> in <module>
#       1 partial_ids = []
# ----> 2 for link in links:
#       3     partial_ids.append(link[0].split('/')[6]) # extrakt partial id
#       4 partial_ids[:11]
#
# NameError: name 'links' is not defined

# %%
title_ids = []
for link in links:
    title_ids.append(link[0].split('fix-')[1].split('.')[0])
title_ids[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bfb046f8308b> in <module>
#       1 title_ids = []
# ----> 2 for link in links:
#       3     title_ids.append(link[0].split('fix-')[1].split('.')[0])
#       4 title_ids[:5]
#
# NameError: name 'links' is not defined

# %%
def get_list_of_recipes_id():
    recipe_links = []
    chef_file = DATAST_FOLDER + 'chefkoch_rezepte_27-12-2017.csv'
    with open(chef_file, 'r') as f:
        chefkoch = csv.reader(f)
        for row in chefkoch:
            try:
                recipe_links.append(row[-2])
            except:
                print('ERROR')
                continue 
    return(recipe_links)

all_ids = get_list_of_recipes_id()
all_ids_clean = []
for id in all_ids[1:]: # erste spalte überspringen, es ist der spalten name
    all_ids_clean.append(id[32:].lower()) # 'recipe-' extrahieren
del all_ids[:]
all_ids_clean[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-a891ac9a2ade> in <module>
#      12     return(recipe_links)
#      13
# ---> 14 all_ids = get_list_of_recipes_id()
#      15 all_ids_clean = []
#      16 for id in all_ids[1:]: # erste spalte überspringen, es ist der spalten name
#
# <ipython-input-23-a891ac9a2ade> in get_list_of_recipes_id()
#       2     recipe_links = []
#       3     chef_file = DATAST_FOLDER + 'chefkoch_rezepte_27-12-2017.csv'
# ----> 4     with open(chef_file, 'r') as f:
#       5         chefkoch = csv.reader(f)
#       6         for row in chefkoch:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input/test/chefkoch_rezepte_27-12-2017.csv'

# %%
print(len(all_ids_clean))
print(len(partial_ids))
print(len(title_ids))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0a09e0661178> in <module>
# ----> 1 print(len(all_ids_clean))
#       2 print(len(partial_ids))
#       3 print(len(title_ids))
#
# NameError: name 'all_ids_clean' is not defined

# %%
# %%time
import json
matches = {} # key: recipe_id , value: pics_list
lost = [] # sichere jede reciped_id wo es keinen match finden konnte => kein match
for i in range(len(title_ids)-1):
    match = [s for s in all_ids_clean if title_ids[i] in s and s.startswith(partial_ids[i])]
    if len(match) == 0: # kein match
        lost.append(i)
        continue
    r_id = match[0].split('/')[0]
    matches[r_id] = links[i]

with open('input/test/matches.txt', 'w') as file:
    file.write(json.dumps(matches))
#print(matches)
print('Lost:', len(lost))
print(lost)

# %% [markdown]
# ## Download von 630'770 Bildern

# %%
from datetime import datetime
from time import sleep
import urllib.request
from multiprocessing import Pool
from random import uniform
import os

# %%
# beispiel: recipe-2841831436245733-1.jpg
IMG_PATH = 'input/images/search_images/'

# %%
def get_img_from_dict(i_dict):
    for idx, linn in enumerate(i_dict[1]):
        try:
            img_name = IMG_PATH + 'recipe-' + str(i_dict[0]) + '-' + str(idx+1) + '.jpg'
            urllib.request.urlretrieve(linn, img_name)
        except:
            print('Error:', i_dict[0])
    sleep_time = uniform(2., 3.) # schone den server mit anfragen
    sleep(sleep_time)

# %%
start_time = datetime.now()
print(start_time)

with Pool(20) as p:
    p.map(get_img_from_dict, matches.items())

print("--- %s seconds ---" % (datetime.now() - start_time))

# %% [markdown]
# Nach fast 5 Stunden sind alle Bilder unter /input/images/search_images/ zu finden. **32.36 GB**
# ### Beispiel:

# %%
import os
from IPython.display import Image, display
PATH = "input/images/search_images/"
images = []
for i in range(1, 10):
    images.append(Image(filename = PATH + "recipe-378801124204434-"+str(i)+".jpg", width=420, height=280))
display(*images)
